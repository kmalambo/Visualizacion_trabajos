# %% [markdown]
# ## Taller 2

# %% [markdown]
# ### Presentado por: Kevin Malambo Alvarez

# %% [markdown]
# ### Base de datos

# %% [markdown]
# La base con la que se va a trabajar es de football  la cual es una red de partidos de fútbol americano entre universidades de la División IA durante la temporada regular Otoño de 2000, esta base fue extraida del portal de la universidad de Michigan. http://www-personal.umich.edu/~mejn/netdata/, y vamos a trabajar con las siguientes librerias.

# %% [markdown]
# #### Librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt

# %% [markdown]
# ### Realización del Network

# %%
g = nx.read_gml('C:/Users/kevin/OneDrive/Escritorio/football.gml')
print("Número de nodos:", g.number_of_nodes())
print("Número de nodos:", g.number_of_edges())
# Out:
# Número de nodos: 115
# Número de nodos: 613

# %%
list(g.nodes)
# Out:
# ['BrighamYoung',
#  'FloridaState',
#  'Iowa',
#  'KansasState',
#  'NewMexico',
#  'TexasTech',
#  'PennState',
#  'SouthernCalifornia',
#  'ArizonaState',
#  'SanDiegoState',
#  'Baylor',
#  'NorthTexas',
#  'NorthernIllinois',
#  'Northwestern',
#  'WesternMichigan',
#  'Wisconsin',
#  'Wyoming',
#  'Auburn',
#  'Akron',
#  'VirginiaTech',
#  'Alabama',
#  'UCLA',
#  'Arizona',
#  'Utah',
#  'ArkansasState',
#  'NorthCarolinaState',
#  'BallState',
#  'Florida',
#  'BoiseState',
#  'BostonCollege',
#  'WestVirginia',
#  'BowlingGreenState',
#  'Michigan',
#  'Virginia',
#  'Buffalo',
#  'Syracuse',
#  'CentralFlorida',
#  'GeorgiaTech',
#  'CentralMichigan',
#  'Purdue',
#  'Colorado',
#  'ColoradoState',
#  'Connecticut',
#  'EasternMichigan',
#  'EastCarolina',
#  'Duke',
#  'FresnoState',
#  'OhioState',
#  'Houston',
#  'Rice',
#  'Idaho',
#  'Washington',
#  'Kansas',
#  'SouthernMethodist',
#  'Kent',
#  'Pittsburgh',
#  'Kentucky',
#  'Louisville',
#  'LouisianaTech',
# ...

# %%
list(g.edges)
# Out:
# [('BrighamYoung', 'FloridaState'),
#  ('BrighamYoung', 'NewMexico'),
#  ('BrighamYoung', 'SanDiegoState'),
#  ('BrighamYoung', 'Wyoming'),
#  ('BrighamYoung', 'Utah'),
#  ('BrighamYoung', 'Virginia'),
#  ('BrighamYoung', 'Syracuse'),
#  ('BrighamYoung', 'ColoradoState'),
#  ('BrighamYoung', 'MississippiState'),
#  ('BrighamYoung', 'UtahState'),
#  ('BrighamYoung', 'AirForce'),
#  ('BrighamYoung', 'NevadaLasVegas'),
#  ('FloridaState', 'NorthCarolinaState'),
#  ('FloridaState', 'Florida'),
#  ('FloridaState', 'Virginia'),
#  ('FloridaState', 'GeorgiaTech'),
#  ('FloridaState', 'Duke'),
#  ('FloridaState', 'Louisville'),
#  ('FloridaState', 'NorthCarolina'),
#  ('FloridaState', 'MiamiFlorida'),
#  ('FloridaState', 'Clemson'),
#  ('FloridaState', 'WakeForest'),
#  ('FloridaState', 'Maryland'),
#  ('Iowa', 'KansasState'),
#  ('Iowa', 'PennState'),
#  ('Iowa', 'Northwestern'),
#  ('Iowa', 'WesternMichigan'),
#  ('Iowa', 'Wisconsin'),
#  ('Iowa', 'OhioState'),
#  ('Iowa', 'Minnesota'),
# ...

# %%
plt.figure(figsize=(50,30))
plt.subplot(121)
plt.title("spring")
nx.draw(g, with_labels=True,pos=nx.spring_layout(g),node_color="plum", 
        node_shape="^", 
        alpha=1, 
        linewidths=30,
        font_weight='bold')

# %% [markdown]
# ## What?, why?, how?

# %% [markdown]
# * **What?** Con respecto a este item tenemos un **Data set Types** de **Network** ya que este grafico cuenta tanto con nodos como con líneas que nos ayuda a conectar cada uno de los diferentes nodos, cabe aclaras que siempre va a ver nodos más conectados que otros, pero ninguno de estos se entra sin conexiones o **links**; con respecto **Attributes** es bastante difícil escoger alguna pero decidí elegir por orden **categorical** ya que ninguno nodos es similar sino todos son distintos porque es un equipo de football diferente, cabe recalcar que para **Datase Availability** es de orden estático porque no está teniendo una cambio con respecto al tiempo.
#
#
#
# * **Why?** los **Actions** para este grafico vendría a ser **Analyze**  y **search** ya que con respecto al primer verbo se tiene **consume** son las subcategorías de **discover** y **present** ya que estamos que equipos de football se están relacionando con nodo y de cómo se están presentando, y con respecto a la segunda categoría solo tendremos en cuenta **Annotate** ya que se tiene el *tag* para cada uno de los nodos; para el segundo verbo se tiene que dar **Location unknown** con un **target unknown** ya que estamos explorando el diferentes nodos con sus relaciones.
#
#   Con respecto al **targets** solo se tendrá en cuenta solo una categoría será **Network Data** de carácter **Topology** ya que se tiene de tiene un gráfico de redes.
#
#
#
# * **How?** el **Encode** es bastante difícil, pero yo decidí elegir el **Arange**, seleccione **Separate** ya que cada uno de los nodos se encuentra en posiciones diferentes, y también utilice la variable **Manipulate** ya que se puede utilizar **Navigate**.

# %% [markdown]
# ## Marcas Y Canales

# %% [markdown]
# * **Marcas**
#    + para las marcas de esta red se tiene  **point** para nodos, **lines** para enlaces.
#
#
# * **Canales**
#
#     + el canal que se tiene para este grafico es espacial ya que no se tiene nigun eje.

# %% [markdown]
# ## Reglas Generales

# %% [markdown]
# Con Respecto a las reglas generales con respecto al 3D Injustificado no corresponderá ninguna ya que el grafico de redes se encuentra en 2D, con las pocas reglas este grafico muestra mucha cantidad de información con las etiquetas de los nodos en un espacio muy pequeño o incluso uno encima del otro, así que una tabla sencilla se podría ver de una manera más organizada y mucho más presentable.

# %% [markdown]
# ## Mejoras Posibles

# %% [markdown]
# Uno de las principales mejoras para este grafico puede ser eliminar el agrupamiento de ciertas áreas para que se pueda ver con más claridad cada uno de los nombres, porque se intentó cambiar la posición, pero evitar el problema de oclusión, pero no se puedo evitar, una última mejora para este grafico será crear una interactividad para poder ver como se relacionan cada uno de los nodos, pero al intentar realizar este tipo de grafico no fue posible.
